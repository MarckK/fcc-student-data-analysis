# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("2016-FCC-New-Coders-Survey-Data.csv", low_memory=False)

# %%
df.columns
# Out:
# Index(['Age', 'AttendedBootcamp', 'BootcampFinish', 'BootcampFullJobAfter',
#        'BootcampLoanYesNo', 'BootcampMonthsAgo', 'BootcampName',
#        'BootcampPostSalary', 'BootcampRecommend', 'ChildrenNumber',
#        ...
#        'ResourceSoloLearn', 'ResourceStackOverflow', 'ResourceTreehouse',
#        'ResourceUdacity', 'ResourceUdemy', 'ResourceW3Schools',
#        'ResourceYouTube', 'SchoolDegree', 'SchoolMajor', 'StudentDebtOwe'],
#       dtype='object', length=113)

# %%
df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber       ...       ResourceSoloLearn  \
# ...

# %%
len(df.columns)
# Out:
# 113

# %%
list(df)
# Out:
# ['Age',
#  'AttendedBootcamp',
#  'BootcampFinish',
#  'BootcampFullJobAfter',
#  'BootcampLoanYesNo',
#  'BootcampMonthsAgo',
#  'BootcampName',
#  'BootcampPostSalary',
#  'BootcampRecommend',
#  'ChildrenNumber',
#  'CityPopulation',
#  'CodeEventBootcamp',
#  'CodeEventCoffee',
#  'CodeEventConferences',
#  'CodeEventDjangoGirls',
#  'CodeEventGameJam',
#  'CodeEventGirlDev',
#  'CodeEventHackathons',
#  'CodeEventMeetup',
#  'CodeEventNodeSchool',
#  'CodeEventNone',
#  'CodeEventOther',
#  'CodeEventRailsBridge',
#  'CodeEventRailsGirls',
#  'CodeEventStartUpWknd',
#  'CodeEventWomenCode',
#  'CodeEventWorkshop',
#  'CommuteTime',
#  'CountryCitizen',
#  'CountryLive',
#  'EmploymentField',
#  'EmploymentFieldOther',
#  'EmploymentStatus',
#  'EmploymentStatusOther',
#  'ExpectedEarning',
#  'FinanciallySupporting',
#  'Gender',
#  'HasChildren',
#  'HasDebt',
#  'HasFinancialDependents',
#  'HasHighSpdInternet',
#  'HasHomeMortgage',
#  'HasServedInMilitary',
# ...

# %%
df.loc[:, 'CountryLive']
# Out:
# 0        United States of America
# 1        United States of America
# 2        United States of America
# 3        United States of America
# 4        United States of America
# 5        United States of America
# 6                       Singapore
# 7                  United Kingdom
# 8        United States of America
# 9        United States of America
# 10       United States of America
# 11                     Bangladesh
# 12                         Canada
# 13       United States of America
# 14                         Russia
# 15       United States of America
# 16       United States of America
# 17                         Canada
# 18                        Croatia
# 19       United States of America
# 20       United States of America
# 21       United States of America
# 22                          India
# 23       United States of America
# 24                   South Africa
# 25       United States of America
# 26       United States of America
# ...

# %%
countries = df['CountryLive']

# %%
df.sort_values(by='CountryLive')
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 3688   62.0               0.0             NaN                   NaN
# 10926  34.0               0.0             NaN                   NaN
# 12207  22.0               NaN             NaN                   NaN
# 12376  22.0               0.0             NaN                   NaN
# 4702   20.0               0.0             NaN                   NaN
# 2011   20.0               0.0             NaN                   NaN
# 11900  20.0               0.0             NaN                   NaN
# 1941   20.0               0.0             NaN                   NaN
# 5464   34.0               0.0             NaN                   NaN
# 3743   22.0               0.0             NaN                   NaN
# 7091   22.0               0.0             NaN                   NaN
# 12141  17.0               0.0             NaN                   NaN
# 11407  17.0               0.0             NaN                   NaN
# ...

# %%
df.CountryLive.unique()
# Out:
# array(['United States of America', 'Singapore', 'United Kingdom',
#        'Bangladesh', 'Canada', 'Russia', 'Croatia', 'India',
#        'South Africa', 'Venezuela', 'Brazil', 'Portugal', nan,
#        'Macedonia', 'Sweden', 'Germany', 'Netherlands (Holland, Europe)',
#        'Pakistan', 'Australia', 'Korea South', 'Austria', 'Belgium',
#        'Republic of Montenegro', 'Bolivia', 'Senegal', 'Ireland',
#        'Romania', 'New Zealand', 'Cambodia', 'Algeria', 'Mexico',
#        'Israel', 'Peru', 'Colombia', 'Hong Kong', 'Ukraine', 'Poland',
#        'Chile', 'Estonia', 'Angola', 'Kazakhstan', 'Slovakia', 'Serbia',
#        'Morocco', 'Denmark', 'Guatemala', 'Argentina', 'Vietnam', 'Japan',
#        'Dominican Republic', 'Philippines', 'Brunei', 'Nigeria', 'China',
#        'Norway', 'United Arab Emirates', 'Trinidad & Tobago', 'Taiwan',
#        'Sri Lanka', 'Costa Rica', 'Lebanon', 'Czech Republic', 'Turkey',
# ...

# %%
unique_countries = df.CountryLive.unique()

# %%
len(unique_countries)
# Out:
# 157

# %%
len(countries)
# Out:
# 15620

# %%
df2 = df.loc[:, ['CountryLive', 'Gender', 'IsSoftwareDev', 'AttendedBootcamp']]

# %%
df2
# Out:
#                     CountryLive  Gender  IsSoftwareDev  AttendedBootcamp
# 0      United States of America    male            0.0               0.0
# 1      United States of America    male            0.0               0.0
# 2      United States of America    male            0.0               0.0
# 3      United States of America  female            0.0               0.0
# 4      United States of America  female            0.0               0.0
# 5      United States of America    male            0.0               0.0
# 6                     Singapore    male            1.0               0.0
# 7                United Kingdom    male            0.0               0.0
# 8      United States of America    male            1.0               0.0
# 9      United States of America    male            0.0               0.0
# 10     United States of America    male            0.0               0.0
# 11                   Bangladesh    male            0.0               0.0
# ...

# %%
usa_female = df2[df2['CountryLive'].isin(['United States of America']) & df2['Gender'].isin(['female'])]

# %%
usa_female
# Out:
#                     CountryLive  Gender  IsSoftwareDev  AttendedBootcamp
# 3      United States of America  female            0.0               0.0
# 4      United States of America  female            0.0               0.0
# 15     United States of America  female            1.0               0.0
# 19     United States of America  female            1.0               0.0
# 20     United States of America  female            1.0               0.0
# 21     United States of America  female            0.0               0.0
# 26     United States of America  female            0.0               0.0
# 29     United States of America  female            0.0               0.0
# 30     United States of America  female            0.0               0.0
# 48     United States of America  female            0.0               0.0
# 53     United States of America  female            0.0               0.0
# 55     United States of America  female            0.0               0.0
# ...

# %%
sums = usa_female.select_dtypes(pd.np.number).sum().rename('total')

# %%
usa_female.append(sums)
# Out:
#                     CountryLive  Gender  IsSoftwareDev  AttendedBootcamp
# 3      United States of America  female            0.0               0.0
# 4      United States of America  female            0.0               0.0
# 15     United States of America  female            1.0               0.0
# 19     United States of America  female            1.0               0.0
# 20     United States of America  female            1.0               0.0
# 21     United States of America  female            0.0               0.0
# 26     United States of America  female            0.0               0.0
# 29     United States of America  female            0.0               0.0
# 30     United States of America  female            0.0               0.0
# 48     United States of America  female            0.0               0.0
# 53     United States of America  female            0.0               0.0
# 55     United States of America  female            0.0               0.0
# ...

# %%
female = df2[df2['Gender'].isin(['female'])]

# %%
female
# Out:
#                     CountryLive  Gender  IsSoftwareDev  AttendedBootcamp
# 3      United States of America  female            0.0               0.0
# 4      United States of America  female            0.0               0.0
# 14                       Russia  female            1.0               0.0
# 15     United States of America  female            1.0               0.0
# 19     United States of America  female            1.0               0.0
# 20     United States of America  female            1.0               0.0
# 21     United States of America  female            0.0               0.0
# 26     United States of America  female            0.0               0.0
# 29     United States of America  female            0.0               0.0
# 30     United States of America  female            0.0               0.0
# 42                        India  female            0.0               0.0
# 48     United States of America  female            0.0               0.0
# ...

# %%
Total = female['AttendedBootcamp'].sum()
print (Total)
# Out:
# 326.0

# %%
sums = female.select_dtypes(pd.np.number).sum().rename('total')

# %%
female.append(sums)
# Out:
#                     CountryLive  Gender  IsSoftwareDev  AttendedBootcamp
# 3      United States of America  female            0.0               0.0
# 4      United States of America  female            0.0               0.0
# 14                       Russia  female            1.0               0.0
# 15     United States of America  female            1.0               0.0
# 19     United States of America  female            1.0               0.0
# 20     United States of America  female            1.0               0.0
# 21     United States of America  female            0.0               0.0
# 26     United States of America  female            0.0               0.0
# 29     United States of America  female            0.0               0.0
# 30     United States of America  female            0.0               0.0
# 42                        India  female            0.0               0.0
# 48     United States of America  female            0.0               0.0
# ...

# %%
df.apply?
# Out:
# Signature: df.apply(func, axis=0, broadcast=None, raw=False, reduce=None, result_type=None, args=(), **kwds)
# Docstring:
# Apply a function along an axis of the DataFrame.
#
# Objects passed to the function are Series objects whose index is
# either the DataFrame's index (``axis=0``) or the DataFrame's columns
# (``axis=1``). By default (``result_type=None``), the final return type
# is inferred from the return type of the applied function. Otherwise,
# it depends on the `result_type` argument.
#
# Parameters
# ----------
# func : function
#     Function to apply to each column or row.
# axis : {0 or 'index', 1 or 'columns'}, default 0
#     Axis along which the function is applied:
#
#     * 0 or 'index': apply function to each column.
#     * 1 or 'columns': apply function to each row.
# broadcast : bool, optional
#     Only relevant for aggregation functions:
#
#     * ``False`` or ``None`` : returns a Series whose length is the
# ...

# %%
df['IsSoftwareDev'] = df['IsSoftwareDev'].apply(bool)

# %%
df['IsSoftwareDev'].head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: IsSoftwareDev, dtype: bool

# %%
fig, ax = plt.subplots()
df.groupby('IsSoftwareDev')['Age'].hist(ax = ax)
ax.set_xlabel('Age')
ax.set_ylabel('count')
ax.legend()
# Out:
# No handles with labels found to put in legend.

# %%
df.groupby('IsSoftwareDev')['Age']

# %%
_37.groups
# Out:
# {False: Int64Index([    0,     1,     2,     3,     4,     5,     7,     9,    10,
#                 11,
#              ...
#              15599, 15600, 15604, 15608, 15612, 15615, 15616, 15617, 15618,
#              15619],
#             dtype='int64', length=11234),
#  True: Int64Index([    6,     8,    14,    15,    17,    19,    20,    34,    45,
#                 54,
#              ...
#              15602, 15603, 15605, 15606, 15607, 15609, 15610, 15611, 15613,
#              15614],
#             dtype='int64', length=4386)}

# %%
_39.groups
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-d7bd53d786da> in <module>()
# ----> 1 _39.groups
#
# NameError: name '_39' is not defined

# %%
fig, (ax, ax2, ax3) = plt.subplots(ncols=3, figsize=(12, 4))
for name, group in df.groupby('IsSoftwareDev')['Age']:
    group.hist(ax = ax, label = 'software dev' if name else 'not software dev', bins = 20)
ax.set_xlabel('Age')
ax.set_ylabel('count')
ax.legend()

fig.tight_layout()
